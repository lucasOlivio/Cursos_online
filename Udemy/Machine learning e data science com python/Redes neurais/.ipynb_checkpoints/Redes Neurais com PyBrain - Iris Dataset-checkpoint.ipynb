# %%
import numpy as np

# carregando os dados com numpy
entradas = np.genfromtxt('iris.data', delimiter=',', usecols=(0,1,2,3))
saidas = np.genfromtxt('iris.data', delimiter=',', usecols=(4))
print(len(entradas))
print(len(saidas))
# Out:
# 150
# 150

# %%
'''
Iris-setosa: 0
Iris-versicolor: 1
Iris-virginica: 2
'''

# mostrando as 5 primeiras amostras que são Iris-setosa
print(entradas[:5])
print(saidas[:5])

print('---------------------')

# mostrando as 5 últimas amostras que são de Iris-virginica
print(entradas[-5:])
print(saidas[-5:])
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]
# [0. 0. 0. 0. 0.]
# ---------------------
# [[6.7 3.  5.2 2.3]
#  [6.3 2.5 5.  1.9]
#  [6.5 3.  5.2 2. ]
#  [6.2 3.4 5.4 2.3]
#  [5.9 3.  5.1 1.8]]
# [2. 2. 2. 2. 2.]

# %%
# vou utilizar 105 amostras para treino sendo 35 de cada classe
entradas_treino = np.concatenate((entradas[:35], entradas[50:85], entradas[100:135]))
saidas_treino = np.concatenate((saidas[:35], saidas[50:85], saidas[100:135]))
print(len(entradas_treino))
print(len(saidas_treino))
# Out:
# 105
# 105

# %%
entradas_teste = np.concatenate((entradas[35:50], entradas[85:100], entradas[135:]))
saidas_teste = np.concatenate((saidas[35:50], saidas[85:100], saidas[135:]))
print(len(entradas_teste))
print(len(saidas_teste))
# Out:
# 45
# 45

# %%
from pybrain.datasets import SupervisedDataSet
from pybrain.tools.shortcuts import buildNetwork
from pybrain.supervised import BackpropTrainer

# %%
treinamento = SupervisedDataSet(4, 1)
for i in range(len(entradas_treino)):
    treinamento.addSample(entradas_treino[i], saidas_treino[i])
print(len(treinamento))
print(treinamento.indim)
print(treinamento.outdim)
# Out:
# 105
# 4
# 1

# %%
# construindo a rede
rede = buildNetwork(treinamento.indim, 2, treinamento.outdim, bias=True)
trainer = BackpropTrainer(rede, treinamento, learningrate=0.01, momentum=0.3)

# treinando a rede
for epoca in range(2000):
    trainer.train()
    
# testando a rede
teste = SupervisedDataSet(4, 1)
for i in range(len(entradas_teste)):
    teste.addSample(entradas_teste[i], saidas_teste[i])
trainer.testOnData(teste, verbose=True)
# Out:
# Testing on data:
# ('out:    ', '[0.022 ]')
# ('correct:', '[0     ]')
# error:  0.00023246
# ('out:    ', '[0.016 ]')
# ('correct:', '[0     ]')
# error:  0.00012532
# ('out:    ', '[0.027 ]')
# ('correct:', '[0     ]')
# error:  0.00036798
# ('out:    ', '[0.033 ]')
# ('correct:', '[0     ]')
# error:  0.00054297
# ('out:    ', '[0.023 ]')
# ('correct:', '[0     ]')
# error:  0.00025927
# ('out:    ', '[0.021 ]')
# ('correct:', '[0     ]')
# error:  0.00021645
# ('out:    ', '[0.069 ]')
# ('correct:', '[0     ]')
# error:  0.00240969
# ('out:    ', '[0.028 ]')
# ('correct:', '[0     ]')
# error:  0.00038062
# ('out:    ', '[0.041 ]')
# ('correct:', '[0     ]')
# error:  0.00085891
# ('out:    ', '[0.03  ]')
# ('correct:', '[0     ]')
# error:  0.00044945
# ('out:    ', '[0.037 ]')
# ('correct:', '[0     ]')
# error:  0.00069739
# ('out:    ', '[0.017 ]')
# ('correct:', '[0     ]')
# error:  0.00015243
# ('out:    ', '[0.029 ]')
# ('correct:', '[0     ]')
# error:  0.00040670
# ('out:    ', '[0.017 ]')
# ('correct:', '[0     ]')
# error:  0.00013784
# ('out:    ', '[0.023 ]')
# ('correct:', '[0     ]')
# error:  0.00027483
# ('out:    ', '[1.102 ]')
# ('correct:', '[1     ]')
# error:  0.00515983
# ('out:    ', '[1.166 ]')
# ('correct:', '[1     ]')
# error:  0.01369692
# ('out:    ', '[1.332 ]')
# ('correct:', '[1     ]')
# error:  0.05507522
# ('out:    ', '[0.922 ]')
# ('correct:', '[1     ]')
# error:  0.00300755
# ('out:    ', '[1.152 ]')
# ('correct:', '[1     ]')
# error:  0.01155558
# ('out:    ', '[1.219 ]')
# ('correct:', '[1     ]')
# error:  0.02406129
# ('out:    ', '[1.181 ]')
# ('correct:', '[1     ]')
# error:  0.01632379
# ('out:    ', '[0.966 ]')
# ('correct:', '[1     ]')
# error:  0.00058402
# ('out:    ', '[0.741 ]')
# ('correct:', '[1     ]')
# error:  0.03344962
# ('out:    ', '[1.132 ]')
# ('correct:', '[1     ]')
# error:  0.00869310
# ('out:    ', '[0.875 ]')
# ('correct:', '[1     ]')
# error:  0.00784637
# ('out:    ', '[1.009 ]')
# ('correct:', '[1     ]')
# error:  0.00004156
# ('out:    ', '[0.979 ]')
# ('correct:', '[1     ]')
# error:  0.00021450
# ('out:    ', '[0.583 ]')
# ('correct:', '[1     ]')
# error:  0.08712528
# ('out:    ', '[1.011 ]')
# ('correct:', '[1     ]')
# error:  0.00006096
# ('out:    ', '[2.062 ]')
# ('correct:', '[2     ]')
# error:  0.00190880
# ('out:    ', '[2.006 ]')
# ('correct:', '[2     ]')
# error:  0.00001597
# ('out:    ', '[1.787 ]')
# ('correct:', '[2     ]')
# error:  0.02269603
# ('out:    ', '[1.608 ]')
# ('correct:', '[2     ]')
# error:  0.07695184
# ('out:    ', '[1.862 ]')
# ('correct:', '[2     ]')
# error:  0.00948847
# ('out:    ', '[2.041 ]')
# ('correct:', '[2     ]')
# error:  0.00084084
# ('out:    ', '[1.871 ]')
# ('correct:', '[2     ]')
# error:  0.00831308
# ('out:    ', '[1.901 ]')
# ('correct:', '[2     ]')
# error:  0.00493417
# ('out:    ', '[2.041 ]')
# ('correct:', '[2     ]')
# error:  0.00083705
# ('out:    ', '[2.051 ]')
# ('correct:', '[2     ]')
# error:  0.00130401
# ('out:    ', '[1.943 ]')
# ('correct:', '[2     ]')
# error:  0.00161328
# ('out:    ', '[1.886 ]')
# ('correct:', '[2     ]')
# error:  0.00645106
# ('out:    ', '[1.821 ]')
# ('correct:', '[2     ]')
# error:  0.01607460
# ('out:    ', '[1.929 ]')
# ('correct:', '[2     ]')
# error:  0.00252233
# ('out:    ', '[1.738 ]')
# ('correct:', '[2     ]')
# error:  0.03419723
# ('All errors:', [0.00023246088370294755, 0.0001253176372708831, 0.00036798487520328123, 0.0005429701070265135, 0.0002592689618514685, 0.00021645097771865853, 0.0024096940742124756, 0.00038062123691881837, 0.0008589084280364801, 0.00044944506939307964, 0.000697391748003611, 0.00015242539662918642, 0.00040670153432985985, 0.00013783724677548525, 0.0002748301696755569, 0.005159831785134637, 0.013696923634047451, 0.05507522168155731, 0.003007550822944025, 0.011555581615611495, 0.024061290018500454, 0.01632378644727674, 0.000584016558794113, 0.03344961763111051, 0.008693102009402615, 0.007846369783391531, 4.156423810324172e-05, 0.00021450162366642113, 0.08712527512716009, 6.09586385155449e-05, 0.0019088028387082947, 1.5966627980392103e-05, 0.022696027061304493, 0.07695183980032752, 0.009488467978602378, 0.0008408415381421978, 0.008313075171709105, 0.004934167883422463, 0.000837047767773595, 0.0013040089177678287, 0.0016132794124203234, 0.006451061873221401, 0.016074598968714496, 0.0025223304334469543, 0.034197227522090735])
# ('Average error:', 0.010279036527946593)
# ('Max error:', 0.08712527512716009, 'Median error:', 0.0016132794124203234)
# 0.010279036527946593

# %%
# construindo a rede
rede = buildNetwork(treinamento.indim, 2, treinamento.outdim, bias=True)
trainer = BackpropTrainer(rede, treinamento, learningrate=0.005, momentum=0.5)

# treinando a rede
for epoca in range(1000):
    trainer.train()
    
# testando a rede
teste = SupervisedDataSet(4, 1)
for i in range(len(entradas_teste)):
    teste.addSample(entradas_teste[i], saidas_teste[i])
trainer.testOnData(teste, verbose=True)
# Out:
# Testing on data:
# ('out:    ', '[0.016 ]')
# ('correct:', '[0     ]')
# error:  0.00012727
# ('out:    ', '[0.008 ]')
# ('correct:', '[0     ]')
# error:  0.00003234
# ('out:    ', '[0.025 ]')
# ('correct:', '[0     ]')
# error:  0.00030366
# ('out:    ', '[0.033 ]')
# ('correct:', '[0     ]')
# error:  0.00053040
# ('out:    ', '[0.018 ]')
# ('correct:', '[0     ]')
# error:  0.00016927
# ('out:    ', '[0.015 ]')
# ('correct:', '[0     ]')
# error:  0.00011746
# ('out:    ', '[0.075 ]')
# ('correct:', '[0     ]')
# error:  0.00278936
# ('out:    ', '[0.026 ]')
# ('correct:', '[0     ]')
# error:  0.00033283
# ('out:    ', '[0.042 ]')
# ('correct:', '[0     ]')
# error:  0.00086608
# ('out:    ', '[0.029 ]')
# ('correct:', '[0     ]')
# error:  0.00042835
# ('out:    ', '[0.037 ]')
# ('correct:', '[0     ]')
# error:  0.00067549
# ('out:    ', '[0.012 ]')
# ('correct:', '[0     ]')
# error:  0.00007078
# ('out:    ', '[0.027 ]')
# ('correct:', '[0     ]')
# error:  0.00035971
# ('out:    ', '[0.01  ]')
# ('correct:', '[0     ]')
# error:  0.00005013
# ('out:    ', '[0.019 ]')
# ('correct:', '[0     ]')
# error:  0.00018275
# ('out:    ', '[1.151 ]')
# ('correct:', '[1     ]')
# error:  0.01141986
# ('out:    ', '[1.186 ]')
# ('correct:', '[1     ]')
# error:  0.01726002
# ('out:    ', '[1.341 ]')
# ('correct:', '[1     ]')
# error:  0.05804049
# ('out:    ', '[0.985 ]')
# ('correct:', '[1     ]')
# error:  0.00010757
# ('out:    ', '[1.193 ]')
# ('correct:', '[1     ]')
# error:  0.01856495
# ('out:    ', '[1.286 ]')
# ('correct:', '[1     ]')
# error:  0.04080344
# ('out:    ', '[1.228 ]')
# ('correct:', '[1     ]')
# error:  0.02601695
# ('out:    ', '[1.008 ]')
# ('correct:', '[1     ]')
# error:  0.00003201
# ('out:    ', '[0.797 ]')
# ('correct:', '[1     ]')
# error:  0.02051873
# ('out:    ', '[1.184 ]')
# ('correct:', '[1     ]')
# error:  0.01690938
# ('out:    ', '[0.945 ]')
# ('correct:', '[1     ]')
# error:  0.00152032
# ('out:    ', '[1.067 ]')
# ('correct:', '[1     ]')
# error:  0.00221532
# ('out:    ', '[1.018 ]')
# ('correct:', '[1     ]')
# error:  0.00016955
# ('out:    ', '[0.623 ]')
# ('correct:', '[1     ]')
# error:  0.07124158
# ('out:    ', '[1.061 ]')
# ('correct:', '[1     ]')
# error:  0.00184416
# ('out:    ', '[2.068 ]')
# ('correct:', '[2     ]')
# error:  0.00233489
# ('out:    ', '[2.027 ]')
# ('correct:', '[2     ]')
# error:  0.00036012
# ('out:    ', '[1.817 ]')
# ('correct:', '[2     ]')
# error:  0.01675830
# ('out:    ', '[1.629 ]')
# ('correct:', '[2     ]')
# error:  0.06889845
# ('out:    ', '[1.862 ]')
# ('correct:', '[2     ]')
# error:  0.00958605
# ('out:    ', '[2.053 ]')
# ('correct:', '[2     ]')
# error:  0.00141292
# ('out:    ', '[1.854 ]')
# ('correct:', '[2     ]')
# error:  0.01070418
# ('out:    ', '[1.925 ]')
# ('correct:', '[2     ]')
# error:  0.00282524
# ('out:    ', '[2.061 ]')
# ('correct:', '[2     ]')
# error:  0.00183149
# ('out:    ', '[2.066 ]')
# ('correct:', '[2     ]')
# error:  0.00217428
# ('out:    ', '[1.939 ]')
# ('correct:', '[2     ]')
# error:  0.00188899
# ('out:    ', '[1.89  ]')
# ('correct:', '[2     ]')
# error:  0.00604877
# ('out:    ', '[1.827 ]')
# ('correct:', '[2     ]')
# error:  0.01491882
# ('out:    ', '[1.948 ]')
# ('correct:', '[2     ]')
# error:  0.00135000
# ('out:    ', '[1.771 ]')
# ('correct:', '[2     ]')
# error:  0.02619503
# ('All errors:', [0.00012726767860170472, 3.233598548671588e-05, 0.00030366384515817464, 0.0005304043204898977, 0.00016926594401001923, 0.00011745564415965912, 0.0027893641960406554, 0.00033283262751251073, 0.0008660849133571047, 0.0004283493351509557, 0.0006754875314109609, 7.077660164387812e-05, 0.00035970777158717107, 5.012552350118555e-05, 0.00018274721432786056, 0.011419855873607793, 0.017260018296289835, 0.058040491816140315, 0.00010757364510512566, 0.018564954559877334, 0.04080344180002267, 0.026016949843259186, 3.200993487597717e-05, 0.02051873358502099, 0.016909375798479967, 0.0015203175379120038, 0.0022153185530965117, 0.00016955481982811228, 0.07124158084883465, 0.0018441641013201549, 0.002334889063196461, 0.00036012093246900724, 0.016758297941149906, 0.06889845308772947, 0.00958605474484942, 0.001412920203650473, 0.01070417961805564, 0.002825235920391079, 0.001831485353861526, 0.0021742797563918024, 0.0018889852343578187, 0.006048773266682168, 0.014918816155089769, 0.0013500003594044167, 0.026195030981946726])
# ('Average error:', 0.010244171839229661)
# ('Max error:', 0.07124158084883465, 'Median error:', 0.0018441641013201549)
# 0.010244171839229661

# %%
# construindo a rede
rede = buildNetwork(treinamento.indim, 2, treinamento.outdim, bias=True)
trainer = BackpropTrainer(rede, treinamento, learningrate=0.01, momentum=0.7)

# treinando a rede
for epoca in range(1000):
    trainer.train()
    
# testando a rede
teste = SupervisedDataSet(4, 1)
for i in range(len(entradas_teste)):
    teste.addSample(entradas_teste[i], saidas_teste[i])
trainer.testOnData(teste, verbose=True)
# Out:
# Testing on data:
# ('out:    ', '[0.037 ]')
# ('correct:', '[0     ]')
# error:  0.00068637
# ('out:    ', '[0.033 ]')
# ('correct:', '[0     ]')
# error:  0.00054644
# ('out:    ', '[0.041 ]')
# ('correct:', '[0     ]')
# error:  0.00082403
# ('out:    ', '[0.045 ]')
# ('correct:', '[0     ]')
# error:  0.00099990
# ('out:    ', '[0.037 ]')
# ('correct:', '[0     ]')
# error:  0.00069499
# ('out:    ', '[0.036 ]')
# ('correct:', '[0     ]')
# error:  0.00064761
# ('out:    ', '[0.076 ]')
# ('correct:', '[0     ]')
# error:  0.00285680
# ('out:    ', '[0.041 ]')
# ('correct:', '[0     ]')
# error:  0.00082487
# ('out:    ', '[0.05  ]')
# ('correct:', '[0     ]')
# error:  0.00124785
# ('out:    ', '[0.041 ]')
# ('correct:', '[0     ]')
# error:  0.00085185
# ('out:    ', '[0.048 ]')
# ('correct:', '[0     ]')
# error:  0.00114746
# ('out:    ', '[0.033 ]')
# ('correct:', '[0     ]')
# error:  0.00055974
# ('out:    ', '[0.041 ]')
# ('correct:', '[0     ]')
# error:  0.00084964
# ('out:    ', '[0.033 ]')
# ('correct:', '[0     ]')
# error:  0.00054957
# ('out:    ', '[0.038 ]')
# ('correct:', '[0     ]')
# error:  0.00071849
# ('out:    ', '[1.172 ]')
# ('correct:', '[1     ]')
# error:  0.01482041
# ('out:    ', '[1.263 ]')
# ('correct:', '[1     ]')
# error:  0.03469644
# ('out:    ', '[1.447 ]')
# ('correct:', '[1     ]')
# error:  0.09988150
# ('out:    ', '[0.973 ]')
# ('correct:', '[1     ]')
# error:  0.00035937
# ('out:    ', '[1.239 ]')
# ('correct:', '[1     ]')
# error:  0.02862946
# ('out:    ', '[1.298 ]')
# ('correct:', '[1     ]')
# error:  0.04434192
# ('out:    ', '[1.264 ]')
# ('correct:', '[1     ]')
# error:  0.03488648
# ('out:    ', '[1.038 ]')
# ('correct:', '[1     ]')
# error:  0.00073409
# ('out:    ', '[0.779 ]')
# ('correct:', '[1     ]')
# error:  0.02437402
# ('out:    ', '[1.211 ]')
# ('correct:', '[1     ]')
# error:  0.02220462
# ('out:    ', '[0.918 ]')
# ('correct:', '[1     ]')
# error:  0.00337261
# ('out:    ', '[1.074 ]')
# ('correct:', '[1     ]')
# error:  0.00270335
# ('out:    ', '[1.053 ]')
# ('correct:', '[1     ]')
# error:  0.00142021
# ('out:    ', '[0.604 ]')
# ('correct:', '[1     ]')
# error:  0.07847237
# ('out:    ', '[1.081 ]')
# ('correct:', '[1     ]')
# error:  0.00324592
# ('out:    ', '[2.059 ]')
# ('correct:', '[2     ]')
# error:  0.00175013
# ('out:    ', '[2.014 ]')
# ('correct:', '[2     ]')
# error:  0.00009854
# ('out:    ', '[1.846 ]')
# ('correct:', '[2     ]')
# error:  0.01188461
# ('out:    ', '[1.693 ]')
# ('correct:', '[2     ]')
# error:  0.04714682
# ('out:    ', '[1.917 ]')
# ('correct:', '[2     ]')
# error:  0.00344323
# ('out:    ', '[2.042 ]')
# ('correct:', '[2     ]')
# error:  0.00089782
# ('out:    ', '[1.928 ]')
# ('correct:', '[2     ]')
# error:  0.00257512
# ('out:    ', '[1.938 ]')
# ('correct:', '[2     ]')
# error:  0.00191030
# ('out:    ', '[2.041 ]')
# ('correct:', '[2     ]')
# error:  0.00082016
# ('out:    ', '[2.048 ]')
# ('correct:', '[2     ]')
# error:  0.00114537
# ('out:    ', '[1.978 ]')
# ('correct:', '[2     ]')
# error:  0.00023125
# ('out:    ', '[1.936 ]')
# ('correct:', '[2     ]')
# error:  0.00205442
# ('out:    ', '[1.881 ]')
# ('correct:', '[2     ]')
# error:  0.00702195
# ('out:    ', '[1.958 ]')
# ('correct:', '[2     ]')
# error:  0.00086733
# ('out:    ', '[1.803 ]')
# ('correct:', '[2     ]')
# error:  0.01942109
# ('All errors:', [0.0006863730575738745, 0.0005464352925533126, 0.0008240317546601657, 0.0009999012240067633, 0.0006949939982874747, 0.000647607957349223, 0.00285680143497079, 0.0008248685455321637, 0.001247850956737704, 0.0008518488144391203, 0.001147461020133231, 0.0005597438634492141, 0.0008496378402977308, 0.0005495722678246909, 0.0007184876322739453, 0.014820411242575257, 0.03469644333838338, 0.0998814957704888, 0.00035936525006701354, 0.028629459472613885, 0.04434191522457145, 0.03488647689176801, 0.0007340905402407371, 0.0243740198371094, 0.022204623952231696, 0.003372613892561064, 0.002703345509578111, 0.0014202085982999702, 0.07847237326617555, 0.0032459176080623818, 0.0017501320335754269, 9.854250226453463e-05, 0.011884611966818817, 0.04714682176052453, 0.0034432321447350426, 0.0008978203032476089, 0.0025751227186087723, 0.001910304191448271, 0.0008201550130255623, 0.0011453650876126552, 0.00023124964245474554, 0.0020544204300413735, 0.007021949389714001, 0.0008673273303764301, 0.01942108800353479])
# ('Average error:', 0.011320367079395526)
# ('Max error:', 0.0998814957704888, 'Median error:', 0.0014202085982999702)
# 0.011320367079395526
